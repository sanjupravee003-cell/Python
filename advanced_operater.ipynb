# %%
a=int(input())
b=int(input())
print(pow(a,b))
# Out:
# 8

# %%
a=23
b=a%10
c=a//10
print(b+c)
# Out:
# 5

# %%
borr=15000
per=2
inter=2.8/100
c=borr*inter
print(c*per)
# Out:
# 839.9999999999999

# %%
a=int(input())
b=int(input())
c=int(input())
d=int(input())
f=(a+c)/2
g=(b+d)/2
print(f,g)
# Out:
# 6.0 9.5

# %%
a=int(input())
b=int(input())
c=a//b
g=c*b
print(c,a-g)
# Out:
# 7 4

# %%
a=int(input())
b=int(input())
c=a//b
g=b*c
print(c,a-g)
# Out:
# 8 2

# %%
a=int(input())
b=a//11
g=b*11
print(b,a-g)
# Out:
# 5 1

# %%
n=int(input())
csa=int(input())
csb=int(input())
toc=int(input())
a=(toc-(csb*n))//(csa-csb)
v=n-a
print(a,v)
# Out:
# 300 98

# %%
a,b=map(float,input().split())
c=10*a
l=40*b
print((c+l)/50)
# Out:
# 5.98

# %%
n=int(input())
b=(n-10)//3
print(b+10,b,b)
# Out:
# 30 20 20

# %%
x=78000
y=60000
a=6*x
b=5*y
c=a*0.50
d=b*0.40
print(c+d)
# Out:
# 354000.0

# %%
nob=0
w=2
byes=3
legbyes=7
pene=1
print(nob+w+byes+legbyes+(pene*5))
# Out:
# 17

# %%
n=100
boa=20
e=80
tp=n+boa+e
a=(n/tp)*100
b=(boa/tp)*100
c=(e/tp)*100
print("%.2f"%a,"%.2f"%b,"%.2f"%c)
# Out:
# 50.00 10.00 40.00

# %%
x=75#distance
y=55#litre
z=63#petrol cost
d=x/y
print((z*d)*30)
# Out:
# 2577.272727272727
