# %%
a=int(input())
if a>0:
    print("positive")
else:
    print("negative")
# Out:
# positive

# %%
n=int(input())
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
n=int(input())
if n>=35:
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
n=int(input())
b=int(input())
if n>=b:
    print("a")
else:
    print("b")
# Out:
# b

# %%
n=int(input())
b=int(input())
c=int(input())
if n>=b and n>=c:
    print("a")
if b>=a and b>=c:
    print("b")
else:
    print("c")
# Out:
# b

# %%
a=int(input())
if a%100==0:
    print("valid")
else:
    print("invalid")
# Out:
# invalid

# %%
a=input()
if  len(a)<6:
    print("weak")
else:
    print("strong")
# Out:
# strong

# %%
a=input()
if a=="green":
    print("go")
elif a=="yellow":
    print("ready")
elif a=="red":
    print("stop")
else:
    print("invalid")
# Out:
# go

# %%
a=input()
if a=="school" or a=="college":
    print("eligible")
else:
    print("invalid")
# Out:
# eligible

# %%
a=input()
if a.isalpha():
    print("alphabet")
elif a.isalnum():
    print("number")
else:
    print("special symbol")
# Out:
# alphabet
