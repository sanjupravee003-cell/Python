# %%
n=int(input())
a=[]
for i in range(0,n):
    a.append(int(input()))
print(sum(a))
# Out:
# 6

# %%
n=int(input())
a=[]
for i in range(0,n):
    a.append(int(input()))
print(max(a))
# Out:
# 78

# %%
n=int(input())
a=[]
for i in range(0,n):
    a.append(int(input()))
a.reverse()
print(a)
# Out:
# [4, 3, 2, 1]

# %%
n=int(input())
a=[]
b=int(input())
for i in range(0,n):
    a.append(int(input()))
if b in a:
    print("Element found")
else:
    print("not")
# Out:
# Element found

# %%
n=int(input())
a=[]
for i in range(0,n):
    a.append(int(input()))
print(a[-1],end=" ")
 
for i in range(0,n-1):
    print(a[i],end=" ")
# Out:
# 5 1 2 3 4

# %%
a=[1,1,2,2,2,3,1,1,4,4]
b=[]
b.append(a[0])
for i in range(0,len(a)-1):
    if a[i]!=a[i+1]:
        b.append(a[i+1])
print(b)
# Out:
# [1, 2, 3, 1, 4]

# %%
a=[10,20,30,40,50]
b=int(input())
c=len(a)
d=c-b
f=[]
for i in range(d,c):
    f.append(a[i])
for i in range(0,d):
    f.append(a[i])
print(f)
# Out:
# [40, 50, 10, 20, 30]

# %%
a=[1,4,6,8]
for i in range(0,len(a)-1):
    if a[i+1]-a[i] == 1:
        continue
    else:
        am=a[i]
        print(am+1)
# Out:
# 2
# 5
# 7
